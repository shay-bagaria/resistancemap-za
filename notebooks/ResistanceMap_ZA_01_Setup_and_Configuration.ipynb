# %% [markdown]
# <a href="https://colab.research.google.com/github/shay-bagaria/resistancemap-za/blob/main/notebooks/ResistanceMap_ZA_01_Setup_and_Configuration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ResistanceMap ZA — Setup and Configuration
#
# This notebook is the entry point for the ResistanceMap ZA computational pipeline.
# It configures the Python environment, verifies access to required libraries,
# and establishes the working directory structure.
#
# **Project:** ResistanceMap ZA
# **Phase:** 1 — Infrastructure Setup
# **Author:** Shay Bagaria
# **Status:** Initialised
